# %%
using BenchmarkTools
using LinearAlgebra
using GLMakie
using StaticArrays

# %% [markdown]
# # S(arg)

# %% [markdown]
# it generate (and return)a scaling matrix. the returned matrix have d+1 row and column where d is the lenght of the array passed as arg

# %%
function s(args...)
	d = length(args)
	mat = Matrix{Float64}(LinearAlgebra.I, d+1, d+1)
	for k in range(1, length=d)
		mat[k,k]=args[k]
	end
	return mat
end
# Out:
# s (generic function with 1 method)

# %%
@btime s(-0.5,-0.5)
# Out:
#   44.141 ns (1 allocation: 160 bytes)
# 3×3 Matrix{Float64}:
#  -0.5   0.0  0.0
#   0.0  -0.5  0.0
#   0.0   0.0  1.0

# %%
@code_llvm s(-0.5,-0.5)
# Out:
# ;  @ In[2]:1 within `s'
# ; Function Attrs: uwtable
# define nonnull {}* @julia_s_1803(double %0, double %1) #0 {
# pass:
# ;  @ In[2]:3 within `s'
# ; ┌ @ C:\buildbot\worker\package_win64\build\usr\share\julia\stdlib\v1.6\LinearAlgebra\src\uniformscaling.jl:471 within `Array'
#    %2 = call nonnull {}* @j_Array_1805([1 x i8]* nocapture readonly @_j_const1, [2 x i64]* nocapture readonly @_j_const2) #0
# ; └
# ;  @ In[2]:5 within `s'
# ; ┌ @ array.jl within `setindex!'
#    %3 = bitcast {}* %2 to {}**
#    %4 = bitcast {}* %2 to double**
#    %5 = getelementptr inbounds {}*, {}** %3, i64 3
#    %6 = bitcast {}** %5 to i64*
# ; └
# ; ┌ @ array.jl:845 within `setindex!'
#    %7 = load i64, i64* %6, align 8
#    %.not = icmp eq i64 %7, 0
#    br i1 %.not, label %oob, label %ib
#
# ib:                                               ; preds = %pass
# ; └
# ; ┌ @ array.jl within `setindex!'
#    %8 = getelementptr inbounds {}*, {}** %3, i64 4
#    %9 = bitcast {}** %8 to i64*
# ; └
# ; ┌ @ array.jl:845 within `setindex!'
#    %10 = load i64, i64* %9, align 8
#    %.not11 = icmp eq i64 %10, 0
#    br i1 %.not11, label %oob, label %pass.1
#
# oob:                                              ; preds = %pass.1, %ib, %pass
#    %value_phi1.lcssa9 = phi i64 [ 1, %ib ], [ 1, %pass ], [ 2, %pass.1 ]
#    %11 = alloca [2 x i64], align 8
#    %.sub = getelementptr inbounds [2 x i64], [2 x i64]* %11, i64 0, i64 0
#    store i64 %value_phi1.lcssa9, i64* %.sub, align 8
#    %12 = getelementptr inbounds [2 x i64], [2 x i64]* %11, i64 0, i64 1
#    store i64 %value_phi1.lcssa9, i64* %12, align 8
#    call void @jl_bounds_error_ints({}* %2, i64* nonnull %.sub, i64 2)
#    unreachable
#
# pass.1:                                           ; preds = %ib
#    %13 = load double*, double** %4, align 8
#    store double %0, double* %13, align 8
#    %14 = icmp ugt i64 %7, 1
#    %15 = icmp ne i64 %10, 1
#    %or.cond = and i1 %14, %15
#    br i1 %or.cond, label %idxend.1, label %oob
#
# idxend.1:                                         ; preds = %pass.1
#    %16 = add nuw nsw i64 %7, 1
#    %17 = getelementptr inbounds double, double* %13, i64 %16
#    store double %1, double* %17, align 8
# ; └
# ;  @ In[2]:7 within `s'
#   ret {}* %2
# }

# %%
@benchmark s(-0.5,-0.5)
# Out:
# BenchmarkTools.Trial: 10000 samples with 985 evaluations.
#  Range (min … max):  47.411 ns …  1.637 μs  ┊ GC (min … max): 0.00% … 0.00%
#  Time  (median):     53.807 ns              ┊ GC (median):    0.00%
#  Time  (mean ± σ):   68.344 ns ± 56.678 ns  ┊ GC (mean ± σ):  2.72% ± 5.04%
#
#   ▇█▅▆▄▃▄▁▁▂                   ▁                              ▂
#   ████████████▇▇▇▆▇▇▇█▇▇▇▇▆▆▅▆██████▇▆▇▇▇▆▆▅▄▆▆▅▅▁▁▅▄▃▄▄▁▄▃▄▄ █
#   47.4 ns      Histogram: log(frequency) by time       297 ns <
#
#  Memory estimate: 160 bytes, allocs estimate: 1.

# %% [markdown]
# # Improvment & changes

# %%
function s(args...)
	d = length(args)
	mat = MMatrix{d+1,d+1,Float64}(1I)
    @inbounds for k in range(1, length=d)
		mat[k,k]=args[k]
	end
	return mat
end
# Out:
# s (generic function with 1 method)

# %%
@btime s(-0.5,-0.5)
# Out:
#   11.400 ns (1 allocation: 80 bytes)
# 3×3 MMatrix{3, 3, Float64, 9} with indices SOneTo(3)×SOneTo(3):
#  -0.5   0.0  0.0
#   0.0  -0.5  0.0
#   0.0   0.0  1.0

# %%
@benchmark s(-0.5,-0.5)
# Out:
# BenchmarkTools.Trial: 10000 samples with 999 evaluations.
#  Range (min … max):  11.512 ns …  2.270 μs  ┊ GC (min … max):  0.00% … 97.65%
#  Time  (median):     12.312 ns              ┊ GC (median):     0.00%
#  Time  (mean ± σ):   18.113 ns ± 83.803 ns  ┊ GC (mean ± σ):  18.75% ±  4.04%
#
#   ██▇▄▃▂▁▁ ▁▂▃▂▁                                    ▁ ▂▁      ▂
#   ███████████████▇▇▆▆▆▆▆▇▆▇▅▅▅▅▆▅▆▄▆▅▄▄▆▄▄▅▄▄▃▃▃▁▃▇▅████▇▇▆▅▅ █
#   11.5 ns      Histogram: log(frequency) by time        52 ns <
#
#  Memory estimate: 80 bytes, allocs estimate: 1.

# %% [markdown]
# # Paralelization

# %%
function sasyn(args...)
	d = length(args)
	mat = MMatrix{d+1,d+1,Float64}(1I)
    @async for k in range(1, length=d)
		mat[k,k]=args[k]
	end
	return mat
end
# Out:
# sasyn (generic function with 1 method)

# %% [markdown]
# ## sync and async made the funcion slower

# %%
@benchmark sasyn(-0.5,-0.5)
# Out:
# BenchmarkTools.Trial: 5368 samples with 651 evaluations.
#  Range (min … max):  482.642 ns …  2.025 ms  ┊ GC (min … max):  0.00% … 99.93%
#  Time  (median):     563.287 ns              ┊ GC (median):     0.00%
#  Time  (mean ± σ):     1.422 μs ± 33.908 μs  ┊ GC (mean ± σ):  57.32% ±  3.05%
#
#      ▄█▆▃▁
#   ▃▄██████▆▅▅▅▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▂▂▂▂▂ ▃
#   483 ns          Histogram: frequency by time         1.29 μs <
#
#  Memory estimate: 608 bytes, allocs estimate: 6.

# %%
function ssimd(args...)
	d = length(args)
	mat = MMatrix{d+1,d+1,Float64}(1I)
    @simd for k in range(1, length=d)
		mat[k,k]=args[k]
	end
	return mat
end
# Out:
# ssimd (generic function with 1 method)

# %% [markdown]
# ## With the usage of simd we improve the old funcion but we still got worse timing

# %%
@benchmark ssimd(-0.5,-0.5)
# Out:
# BenchmarkTools.Trial: 10000 samples with 999 evaluations.
#  Range (min … max):  12.613 ns …  1.771 μs  ┊ GC (min … max):  0.00% … 94.37%
#  Time  (median):     14.114 ns              ┊ GC (median):     0.00%
#  Time  (mean ± σ):   19.963 ns ± 68.910 ns  ┊ GC (mean ± σ):  13.84% ±  4.02%
#
#   ▅█▅▁▃▁  ▁▂▁                                                 ▁
#   ███████████▇▆▇█▇▆▅▅▅▄▃▁▄▄▄▃▃▁▁▁▁▁▁▃▁▁▁▁▁▁▃▁▃▅▆▆██████▇▇▇▆▆▆ █
#   12.6 ns      Histogram: log(frequency) by time      74.3 ns <
#
#  Memory estimate: 80 bytes, allocs estimate: 1.

# %% [markdown]
# # Using threads the funcion is faster then the async but slowen then simd
# ## (tested with 4 threads)

# %%
Threads.nthreads()
# Out:
# 4

# %%
function sthread(args...)
	d = length(args)
	mat = MMatrix{d+1,d+1,Float64}(1I)
    Threads.@spawn for k in range(1, length=d)
		mat[k,k]=args[k]
	end
	return mat
end
# Out:
# sthread (generic function with 1 method)

# %%
@benchmark sthread(-0.5,-0.5)
# Out:
# BenchmarkTools.Trial: 10000 samples with 811 evaluations.
#  Range (min … max):  296.547 ns …   8.787 μs  ┊ GC (min … max):  0.00% … 91.15%
#  Time  (median):     483.107 ns               ┊ GC (median):     0.00%
#  Time  (mean ± σ):   544.948 ns ± 594.409 ns  ┊ GC (mean ± σ):  11.17% ±  9.44%
#
#    ▂█
#   ▃██▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂ ▂
#   297 ns           Histogram: frequency by time          5.5 μs <
#
#  Memory estimate: 620 bytes, allocs estimate: 6.

# %%
function get_times(func,N)
    times = Float64[]
    for n in N
        bench = @benchmark $func($(-0.5),$(-0.5))
        push!(times, minimum(bench.times))
    end
    return times
end
# Out:
# get_times (generic function with 1 method)

# %%
N = range(1, 4, step=1)
times1 = get_times(s,N)
# Out:
# 4-element Vector{Float64}:
#  12.4
#  12.4
#  12.312312312312311
#  12.5

# %%
times2 = get_times(sasyn,N)
# Out:
# 4-element Vector{Float64}:
#  414.2191142191142
#  456.1576354679803
#  500.0
#  470.7070707070707

# %%
times3 = get_times(ssimd,N)
# Out:
# 4-element Vector{Float64}:
#  12.812812812812814
#  12.751004016064257
#  24.424424424424423
#  12.4

# %%
times4 = get_times(sthread,N)
# Out:
# 4-element Vector{Float64}:
#  189.3835616438356
#  357.0
#  290.4593639575972
#  205.60747663551402

# %%
fig = Figure(resolution = (1000,500))
ax = Axis(fig[1, 1], xlabel="N", ylabel="Performance")

fig = lines!(ax, N, N ./ times1)
# Out:
# UndefVarError: fig not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[12]:2
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1116

# %%
l2 = lines!(ax, N, N ./ times2)
l3 = lines!(ax, N, N ./ times3)
l4 = lines!(ax, N, N ./ times4)

fig[1, 2] = Legend(fig, [l1, l2, l3, l4], ["@inbounds", "@async", "@simd", "Thread.@spawn"])

display(fig)
